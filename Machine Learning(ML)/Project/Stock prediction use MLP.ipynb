# %% [markdown]
# # Download Data

# %%
import yfinance as yf
ETF = "006208.TW"
History = "10y"
all_day_k = yf.Ticker(ETF).history(period = History, interval = "1d")

all_day_k
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2014-05-22 00:00:00+08:00  25.388357  25.591347  25.388357  25.591347
# 2014-05-23 00:00:00+08:00  25.663844  25.700092  25.627593  25.678341
# 2014-05-26 00:00:00+08:00  25.787086  25.787086  25.787086  25.787086
# 2014-05-27 00:00:00+08:00  25.801580  25.830580  25.794332  25.830580
# 2014-05-28 00:00:00+08:00  26.098822  26.098822  26.098822  26.098822
# ...                              ...        ...        ...        ...
# 2024-05-16 00:00:00+08:00  98.699997  99.300003  97.849998  98.099998
# 2024-05-17 00:00:00+08:00  98.099998  98.199997  97.650002  97.800003
# 2024-05-20 00:00:00+08:00  97.900002  98.000000  96.750000  97.650002
# 2024-05-21 00:00:00+08:00  97.599998  97.750000  97.050003  97.599998
# 2024-05-22 00:00:00+08:00  97.750000  99.550003  97.750000  99.500000
#
#                             Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2014-05-22 00:00:00+08:00   133000        0.0           0.0            0.0
# 2014-05-23 00:00:00+08:00     8000        0.0           0.0            0.0
# 2014-05-26 00:00:00+08:00     1000        0.0           0.0            0.0
# 2014-05-27 00:00:00+08:00    11000        0.0           0.0            0.0
# 2014-05-28 00:00:00+08:00     2000        0.0           0.0            0.0
# ...                            ...        ...           ...            ...
# 2024-05-16 00:00:00+08:00  7812350        0.0           0.0            0.0
# 2024-05-17 00:00:00+08:00  3381637        0.0           0.0            0.0
# 2024-05-20 00:00:00+08:00  5298248        0.0           0.0            0.0
# 2024-05-21 00:00:00+08:00  2494702        0.0           0.0            0.0
# 2024-05-22 00:00:00+08:00  4254038        0.0           0.0            0.0
#
# [2439 rows x 8 columns]

# %% [markdown]
# # Filter data

# %%
all_day_k = all_day_k.drop(columns=["Dividends", "Stock Splits","Capital Gains"])
all_day_k = all_day_k[:-1]
all_day_k
# Out:
#                                 Open       High        Low      Close   Volume
# Date
# 2014-05-22 00:00:00+08:00  25.388357  25.591347  25.388357  25.591347   133000
# 2014-05-23 00:00:00+08:00  25.663844  25.700092  25.627593  25.678341     8000
# 2014-05-26 00:00:00+08:00  25.787086  25.787086  25.787086  25.787086     1000
# 2014-05-27 00:00:00+08:00  25.801580  25.830580  25.794332  25.830580    11000
# 2014-05-28 00:00:00+08:00  26.098822  26.098822  26.098822  26.098822     2000
# ...                              ...        ...        ...        ...      ...
# 2024-05-15 00:00:00+08:00  96.650002  98.199997  96.650002  97.500000  4232415
# 2024-05-16 00:00:00+08:00  98.699997  99.300003  97.849998  98.099998  7812350
# 2024-05-17 00:00:00+08:00  98.099998  98.199997  97.650002  97.800003  3381637
# 2024-05-20 00:00:00+08:00  97.900002  98.000000  96.750000  97.650002  5298248
# 2024-05-21 00:00:00+08:00  97.599998  97.750000  97.050003  97.599998  2494702
#
# [2438 rows x 5 columns]

# %% [markdown]
# # Construct dataset

# %%
import numpy as np
import pandas as pd

PAST_WIN_LEN = 100
CLASSES = ["Bull", "Bear"]
LABEL_BULL = CLASSES.index("Bull")
LABEL_BEAR = CLASSES.index("Bear")

x, y = [], []
for today_i in range(len(all_day_k)):
    day_k_past = all_day_k[:today_i + 1]
    day_k_forward = all_day_k[today_i + 1:]
    if len(day_k_past) < PAST_WIN_LEN or len(day_k_forward) < 1:
        continue
    day_k_past_win = day_k_past[-PAST_WIN_LEN:]
    day_k_forward_win = day_k_forward[:1]

    today_price = day_k_past_win.iloc[-1]["Close"]
    tomorrow_price = day_k_forward_win.iloc[0]["Close"]
    label = LABEL_BULL if tomorrow_price > today_price else LABEL_BEAR

    x.append(day_k_past_win.values)
    y.append(label)

x, y = np.array(x), np.array(y)

# %%
x.shape
# Out:
# (2338, 100, 5)

# %%
x
# Out:
# array([[[2.53883568e+01, 2.55913467e+01, 2.53883568e+01, 2.55913467e+01,
#          1.33000000e+05],
#         [2.56638440e+01, 2.57000918e+01, 2.56275934e+01, 2.56783409e+01,
#          8.00000000e+03],
#         [2.57870865e+01, 2.57870865e+01, 2.57870865e+01, 2.57870865e+01,
#          1.00000000e+03],
#         ...,
#         [2.71282768e+01, 2.71862755e+01, 2.71282768e+01, 2.71862755e+01,
#          5.10000000e+04],
#         [2.70557805e+01, 2.70557805e+01, 2.64613075e+01, 2.64613075e+01,
#          1.20000000e+04],
#         [2.68165474e+01, 2.68165474e+01, 2.68165474e+01, 2.68165474e+01,
#          0.00000000e+00]],
#
#        [[2.56638440e+01, 2.57000918e+01, 2.56275934e+01, 2.56783409e+01,
#          8.00000000e+03],
#         [2.57870865e+01, 2.57870865e+01, 2.57870865e+01, 2.57870865e+01,
#          1.00000000e+03],
#         [2.58015804e+01, 2.58305798e+01, 2.57943320e+01, 2.58305798e+01,
#          1.10000000e+04],
#         ...,
#         [2.70557805e+01, 2.70557805e+01, 2.64613075e+01, 2.64613075e+01,
#          1.20000000e+04],
#         [2.68165474e+01, 2.68165474e+01, 2.68165474e+01, 2.68165474e+01,
#          0.00000000e+00],
#         [2.66135495e+01, 2.66135495e+01, 2.64830551e+01, 2.64830551e+01,
#          2.00000000e+03]],
#
#        [[2.57870865e+01, 2.57870865e+01, 2.57870865e+01, 2.57870865e+01,
#          1.00000000e+03],
#         [2.58015804e+01, 2.58305798e+01, 2.57943320e+01, 2.58305798e+01,
#          1.10000000e+04],
#         [2.60988216e+01, 2.60988216e+01, 2.60988216e+01, 2.60988216e+01,
#          2.00000000e+03],
#         ...,
#         [2.68165474e+01, 2.68165474e+01, 2.68165474e+01, 2.68165474e+01,
#          0.00000000e+00],
#         [2.66135495e+01, 2.66135495e+01, 2.64830551e+01, 2.64830551e+01,
#          2.00000000e+03],
#         [2.62510661e+01, 2.63380642e+01, 2.60770755e+01, 2.63380642e+01,
#          5.00000000e+03]],
#
#        ...,
#
#        [[7.50500031e+01, 7.51500015e+01, 7.49499969e+01, 7.50500031e+01,
#          2.27742400e+06],
#         [7.56999969e+01, 7.60000000e+01, 7.55500031e+01, 7.58000031e+01,
#          7.17910500e+06],
#         [7.61500015e+01, 7.63000031e+01, 7.59499969e+01, 7.60500031e+01,
#          7.67825900e+06],
#         ...,
#         [9.53000031e+01, 9.61500015e+01, 9.51999969e+01, 9.61500015e+01,
#          2.69074300e+06],
#         [9.66500015e+01, 9.81999969e+01, 9.66500015e+01, 9.75000000e+01,
#          4.23241500e+06],
#         [9.86999969e+01, 9.93000031e+01, 9.78499985e+01, 9.80999985e+01,
#          7.81235000e+06]],
#
#        [[7.56999969e+01, 7.60000000e+01, 7.55500031e+01, 7.58000031e+01,
#          7.17910500e+06],
#         [7.61500015e+01, 7.63000031e+01, 7.59499969e+01, 7.60500031e+01,
#          7.67825900e+06],
#         [7.60500031e+01, 7.61500015e+01, 7.55999985e+01, 7.60999985e+01,
#          4.97162500e+06],
#         ...,
#         [9.66500015e+01, 9.81999969e+01, 9.66500015e+01, 9.75000000e+01,
#          4.23241500e+06],
#         [9.86999969e+01, 9.93000031e+01, 9.78499985e+01, 9.80999985e+01,
#          7.81235000e+06],
#         [9.80999985e+01, 9.81999969e+01, 9.76500015e+01, 9.78000031e+01,
#          3.38163700e+06]],
#
#        [[7.61500015e+01, 7.63000031e+01, 7.59499969e+01, 7.60500031e+01,
#          7.67825900e+06],
#         [7.60500031e+01, 7.61500015e+01, 7.55999985e+01, 7.60999985e+01,
#          4.97162500e+06],
#         [7.60999985e+01, 7.62500000e+01, 7.56999969e+01, 7.59499969e+01,
#          3.00300600e+06],
#         ...,
#         [9.86999969e+01, 9.93000031e+01, 9.78499985e+01, 9.80999985e+01,
#          7.81235000e+06],
#         [9.80999985e+01, 9.81999969e+01, 9.76500015e+01, 9.78000031e+01,
#          3.38163700e+06],
#         [9.79000015e+01, 9.80000000e+01, 9.67500000e+01, 9.76500015e+01,
#          5.29824800e+06]]])

# %%
y.shape
# Out:
# (2338,)

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# # Split dataset to training/validation/test datasets

# %%
TRAIN_SPLIT, VAL_SPLIT, TEST_SPLIT = 0.7, 0.2, 0.1

test_split_index = -round(len(x) * TEST_SPLIT)
x_other, x_test = np.split(x, [test_split_index])
y_other, y_test = np.split(y, [test_split_index])

train_split_index = round(len(x) * TRAIN_SPLIT)
indexes = np.arange(len(x_other))
np.random.shuffle(indexes)
train_indexes, val_indexes = np.split(indexes, [train_split_index])
x_train, x_val = x_other[train_indexes], x_other[val_indexes]
y_train, y_val = y_other[train_indexes], y_other[val_indexes]

# %%
label_distribution = pd.DataFrame([
                                {"Dataset": "train",
                                    "Bull": np.count_nonzero(y_train == LABEL_BULL),
                                    "Bear": np.count_nonzero(y_train == LABEL_BEAR)},
                                {"Dataset": "val",
                                    "Bull": np.count_nonzero(y_val == LABEL_BULL),
                                    "Bear": np.count_nonzero(y_val == LABEL_BEAR)},
                                {"Dataset": "test",
                                    "Bull": np.count_nonzero(y_test == LABEL_BEAR),
                                    "Bear": np.count_nonzero(y_test == LABEL_BEAR),}])

label_distribution
# Out:
#   Dataset  Bull  Bear
# 0   train   824   813
# 1     val   217   250
# 2    test   108   108

# %%
x_test_bull = x_test[y_test == LABEL_BULL]
x_test_bear = x_test[y_test == LABEL_BEAR]

min_n_labels = min(len(x_test_bull), len(x_test_bear))

x_test_bull = x_test_bull[np.random.choice(len(x_test_bull), min_n_labels, replace=False), :]
x_test_bear = x_test_bear[np.random.choice(len(x_test_bear), min_n_labels, replace=False), :]
x_test = np.vstack([x_test_bull, x_test_bear])

y_test = np.array([LABEL_BULL] * min_n_labels + [LABEL_BEAR] * min_n_labels)

pd.DataFrame([
            {"Dataset": "test",
                "Bull": np.count_nonzero(y_test == LABEL_BEAR),
                "Bear": np.count_nonzero(y_test == LABEL_BEAR)}])
# Out:
#   Dataset  Bull  Bear
# 0    test   108   108

# %%
x_train.shape
# Out:
# (1637, 100, 5)

# %%
1637 * 100 * 5
# Out:
# 818500

# %% [markdown]
# # Save datasets

# %%
np.savez("datasets.npz", x_train = x_train, y_train = y_train, x_val = x_val, y_val = y_val, 
         x_test = x_test, y_test = y_test)

# %% [markdown]
# # Construct model

# %%
from tensorflow.keras.layers import Input, Flatten, Dense
from tensorflow.keras.models import Model

n_time_steps = x_train.shape[1]
n_features = x_train.shape[2]

input_layer = Input(shape = (n_time_steps, n_features))
x = Flatten()(input_layer)
x = Dense(256, activation='relu')(x)
x = Dense(256, activation='relu')(x)
output_layer = Dense(len(CLASSES), activation="softmax")(x)

model = Model(inputs = input_layer, outputs = output_layer)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100, 5)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 500)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       128,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 194,562 (760.01 KB)
#  Trainable params: 194,562 (760.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Train model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.python.keras.utils import np_utils

model.compile(loss = "categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model_checkpoint = ModelCheckpoint(filepath="best_model_MLP.keras", monitor="val_loss", save_best_only=True)

early_stopping = EarlyStopping(monitor="val_loss", patience=100, restore_best_weights=True)
callbacks = [model_checkpoint, early_stopping]

train_history = model.fit(
    x_train,
    np_utils.to_categorical(y_train),
    validation_data = (x_val, np_utils.to_categorical(y_val)),
    batch_size = 2048,
    epochs = 1000,
    callbacks=[callbacks])
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5058 - loss: 197264.0156 - val_accuracy: 0.5353 - val_loss: 582158.3125
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4973 - loss: 634298.5000 - val_accuracy: 0.5375 - val_loss: 461765.7500
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4997 - loss: 503997.4062 - val_accuracy: 0.5161 - val_loss: 172063.2656
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5034 - loss: 195368.2500 - val_accuracy: 0.4946 - val_loss: 176144.8438
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5095 - loss: 164933.4531 - val_accuracy: 0.4668 - val_loss: 287128.3125
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5046 - loss: 276232.5000 - val_accuracy: 0.4690 - val_loss: 255061.3281
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5027 - loss: 243403.6094 - val_accuracy: 0.4861 - val_loss: 140612.9375
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5040 - loss: 128303.7656 - val_accuracy: 0.5032 - val_loss: 60326.2266
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5199 - loss: 61908.6445 - val_accuracy: 0.5054 - val_loss: 125308.8281
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5119 - loss: 134893.4688 - val_accuracy: 0.5161 - val_loss: 143820.3750
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5107 - loss: 153668.8906 - val_accuracy: 0.5075 - val_loss: 109335.8594
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5180 - loss: 113712.5703 - val_accuracy: 0.4904 - val_loss: 56719.0508
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5199 - loss: 52480.6484 - val_accuracy: 0.5032 - val_loss: 69946.8594
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5418 - loss: 57300.6445 - val_accuracy: 0.4818 - val_loss: 107795.2188
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5199 - loss: 93142.5938 - val_accuracy: 0.4797 - val_loss: 106575.6953
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5205 - loss: 91500.4062 - val_accuracy: 0.4861 - val_loss: 72304.1016
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5455 - loss: 57938.9414 - val_accuracy: 0.4732 - val_loss: 45121.6797
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5461 - loss: 32548.4160 - val_accuracy: 0.4925 - val_loss: 64418.8398
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5266 - loss: 53407.3008 - val_accuracy: 0.4946 - val_loss: 79365.5156
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5308 - loss: 67743.6797 - val_accuracy: 0.5032 - val_loss: 67570.5156
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5315 - loss: 54477.1836 - val_accuracy: 0.4711 - val_loss: 45017.2031
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5437 - loss: 29196.4355 - val_accuracy: 0.4946 - val_loss: 45919.1758
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5651 - loss: 29145.0117 - val_accuracy: 0.4904 - val_loss: 62269.0234
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5583 - loss: 45300.5391 - val_accuracy: 0.4861 - val_loss: 61234.1797
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5553 - loss: 43949.3867 - val_accuracy: 0.4925 - val_loss: 44803.8359
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5614 - loss: 27012.0957 - val_accuracy: 0.4540 - val_loss: 36823.6719
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5693 - loss: 19661.6562 - val_accuracy: 0.4946 - val_loss: 46784.2578
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5547 - loss: 30119.0938 - val_accuracy: 0.4818 - val_loss: 49794.9453
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5589 - loss: 32893.1445 - val_accuracy: 0.4989 - val_loss: 40042.4531
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5791 - loss: 22274.2520 - val_accuracy: 0.4818 - val_loss: 33627.2539
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5870 - loss: 14926.4951 - val_accuracy: 0.4968 - val_loss: 39633.1094
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5791 - loss: 21354.6367 - val_accuracy: 0.4904 - val_loss: 42652.5625
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5809 - loss: 24517.9785 - val_accuracy: 0.4904 - val_loss: 36529.1641
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5840 - loss: 17706.0312 - val_accuracy: 0.4861 - val_loss: 31456.7051
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6109 - loss: 11527.5459 - val_accuracy: 0.4732 - val_loss: 36365.9297
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5968 - loss: 16418.2852 - val_accuracy: 0.4711 - val_loss: 38130.0273
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5980 - loss: 18138.9492 - val_accuracy: 0.4904 - val_loss: 32747.6523
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6164 - loss: 11726.6562 - val_accuracy: 0.5096 - val_loss: 30763.9121
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6261 - loss: 10059.8066 - val_accuracy: 0.5011 - val_loss: 33641.6602
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6170 - loss: 14041.2178 - val_accuracy: 0.4968 - val_loss: 32792.9688
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6219 - loss: 12811.4150 - val_accuracy: 0.5011 - val_loss: 30031.2656
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6426 - loss: 8294.5732 - val_accuracy: 0.5032 - val_loss: 31284.2949
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6292 - loss: 9200.0000 - val_accuracy: 0.4925 - val_loss: 33466.2930
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6255 - loss: 11152.2979 - val_accuracy: 0.4989 - val_loss: 31495.6445
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6371 - loss: 8587.7773 - val_accuracy: 0.5054 - val_loss: 29999.3320
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6542 - loss: 6664.0479 - val_accuracy: 0.4946 - val_loss: 31453.1152
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6402 - loss: 8952.4639 - val_accuracy: 0.4968 - val_loss: 31266.1387
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6445 - loss: 8540.4492 - val_accuracy: 0.4946 - val_loss: 29719.2812
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6640 - loss: 5797.0361 - val_accuracy: 0.4925 - val_loss: 30155.8691
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6604 - loss: 6123.6831 - val_accuracy: 0.4925 - val_loss: 31046.4746
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6506 - loss: 7229.6050 - val_accuracy: 0.4904 - val_loss: 29388.4629
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.6689 - loss: 5475.0786 - val_accuracy: 0.5054 - val_loss: 28266.9082
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6866 - loss: 4606.3975 - val_accuracy: 0.5054 - val_loss: 28711.5879
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6775 - loss: 5676.9077 - val_accuracy: 0.5032 - val_loss: 28105.3750
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6854 - loss: 4948.0137 - val_accuracy: 0.5054 - val_loss: 27368.2637
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6940 - loss: 3788.6389 - val_accuracy: 0.4989 - val_loss: 27981.5547
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6793 - loss: 4535.8970 - val_accuracy: 0.4925 - val_loss: 27874.3066
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6817 - loss: 4423.2769 - val_accuracy: 0.4968 - val_loss: 26859.3574
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6970 - loss: 3204.8914 - val_accuracy: 0.4989 - val_loss: 26948.4258
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7043 - loss: 3451.5618 - val_accuracy: 0.4925 - val_loss: 27067.0234
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7037 - loss: 3754.2102 - val_accuracy: 0.4946 - val_loss: 26472.1543
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7129 - loss: 2755.7356 - val_accuracy: 0.5011 - val_loss: 26546.9648
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7098 - loss: 2788.2185 - val_accuracy: 0.4925 - val_loss: 26776.2598
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7037 - loss: 3081.0410 - val_accuracy: 0.5054 - val_loss: 26221.0840
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7227 - loss: 2432.0518 - val_accuracy: 0.4946 - val_loss: 26008.5586
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7330 - loss: 2249.1189 - val_accuracy: 0.4882 - val_loss: 26021.5820
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7214 - loss: 2525.8857 - val_accuracy: 0.4989 - val_loss: 25854.4082
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7404 - loss: 2076.1724 - val_accuracy: 0.5118 - val_loss: 25874.8789
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7410 - loss: 1952.4907 - val_accuracy: 0.4925 - val_loss: 26085.5430
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7294 - loss: 2098.8877 - val_accuracy: 0.4968 - val_loss: 25942.3457
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7367 - loss: 1931.2325 - val_accuracy: 0.5096 - val_loss: 25683.5723
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7495 - loss: 1676.2274 - val_accuracy: 0.5011 - val_loss: 25584.3086
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7575 - loss: 1717.0686 - val_accuracy: 0.4946 - val_loss: 25513.4316
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7544 - loss: 1727.1667 - val_accuracy: 0.5118 - val_loss: 25390.6816
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7569 - loss: 1474.5297 - val_accuracy: 0.4989 - val_loss: 25412.5195
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7550 - loss: 1461.6266 - val_accuracy: 0.5032 - val_loss: 25349.1484
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7538 - loss: 1452.0278 - val_accuracy: 0.5011 - val_loss: 25102.5742
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7740 - loss: 1240.7559 - val_accuracy: 0.4989 - val_loss: 24961.1465
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7752 - loss: 1276.7711 - val_accuracy: 0.4989 - val_loss: 24850.1484
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7813 - loss: 1199.2991 - val_accuracy: 0.4989 - val_loss: 24804.0664
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7880 - loss: 1092.7802 - val_accuracy: 0.5054 - val_loss: 24821.9102
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7746 - loss: 1134.5400 - val_accuracy: 0.5054 - val_loss: 24700.5234
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7886 - loss: 1017.4045 - val_accuracy: 0.5096 - val_loss: 24629.1406
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7954 - loss: 987.7557 - val_accuracy: 0.5032 - val_loss: 24613.2891
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7954 - loss: 980.6633 - val_accuracy: 0.5075 - val_loss: 24609.8848
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8064 - loss: 898.4470 - val_accuracy: 0.5118 - val_loss: 24666.0254
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7954 - loss: 923.7180 - val_accuracy: 0.5118 - val_loss: 24625.1133
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8027 - loss: 860.8411 - val_accuracy: 0.5118 - val_loss: 24551.7383
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8143 - loss: 823.5699 - val_accuracy: 0.5182 - val_loss: 24546.5332
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8119 - loss: 840.7198 - val_accuracy: 0.5096 - val_loss: 24516.7520
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8149 - loss: 765.7570 - val_accuracy: 0.5118 - val_loss: 24548.2168
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8125 - loss: 749.5919 - val_accuracy: 0.5054 - val_loss: 24554.5781
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8076 - loss: 745.0134 - val_accuracy: 0.5118 - val_loss: 24463.2871
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8235 - loss: 684.0165 - val_accuracy: 0.5139 - val_loss: 24410.4941
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8283 - loss: 658.3954 - val_accuracy: 0.5225 - val_loss: 24395.8789
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8296 - loss: 656.8950 - val_accuracy: 0.5161 - val_loss: 24369.8164
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8314 - loss: 607.0411 - val_accuracy: 0.5096 - val_loss: 24403.0098
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8253 - loss: 585.4917 - val_accuracy: 0.5075 - val_loss: 24368.9473
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8277 - loss: 567.4588 - val_accuracy: 0.5118 - val_loss: 24240.1094
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8406 - loss: 531.8953 - val_accuracy: 0.5225 - val_loss: 24135.9102
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8400 - loss: 535.7296 - val_accuracy: 0.5182 - val_loss: 24069.3535
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8430 - loss: 503.1172 - val_accuracy: 0.5075 - val_loss: 24041.0742
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8448 - loss: 481.9376 - val_accuracy: 0.5075 - val_loss: 23995.9375
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8454 - loss: 467.0465 - val_accuracy: 0.5182 - val_loss: 23938.7754
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8528 - loss: 446.9354 - val_accuracy: 0.5182 - val_loss: 23911.0527
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8564 - loss: 428.3854 - val_accuracy: 0.5182 - val_loss: 23893.5859
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8571 - loss: 411.9807 - val_accuracy: 0.5118 - val_loss: 23885.6641
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8516 - loss: 400.4259 - val_accuracy: 0.5182 - val_loss: 23876.4629
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8601 - loss: 383.6956 - val_accuracy: 0.5139 - val_loss: 23879.3770
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8638 - loss: 376.2969 - val_accuracy: 0.5139 - val_loss: 23907.6465
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8650 - loss: 355.7707 - val_accuracy: 0.5182 - val_loss: 23957.0469
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8619 - loss: 347.2005 - val_accuracy: 0.5118 - val_loss: 24004.2227
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8662 - loss: 328.8991 - val_accuracy: 0.5161 - val_loss: 23967.2168
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8668 - loss: 317.8781 - val_accuracy: 0.5118 - val_loss: 23963.0137
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8705 - loss: 306.2278 - val_accuracy: 0.5118 - val_loss: 23951.8027
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8760 - loss: 295.8697 - val_accuracy: 0.5139 - val_loss: 23940.2676
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8748 - loss: 286.8420 - val_accuracy: 0.5139 - val_loss: 23920.4297
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8797 - loss: 279.5733 - val_accuracy: 0.5161 - val_loss: 23894.4863
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8772 - loss: 268.1290 - val_accuracy: 0.5139 - val_loss: 23874.4727
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8827 - loss: 258.0205 - val_accuracy: 0.5161 - val_loss: 23861.5703
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8858 - loss: 251.5786 - val_accuracy: 0.5139 - val_loss: 23861.3477
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8919 - loss: 240.4827 - val_accuracy: 0.5161 - val_loss: 23862.9941
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8876 - loss: 236.5739 - val_accuracy: 0.5139 - val_loss: 23835.7832
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8931 - loss: 225.3657 - val_accuracy: 0.5139 - val_loss: 23821.8477
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8980 - loss: 217.3622 - val_accuracy: 0.5118 - val_loss: 23816.7031
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8986 - loss: 210.2700 - val_accuracy: 0.5118 - val_loss: 23852.9473
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9035 - loss: 203.0726 - val_accuracy: 0.5139 - val_loss: 23898.0312
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9023 - loss: 197.9002 - val_accuracy: 0.5118 - val_loss: 23929.2910
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9016 - loss: 190.8038 - val_accuracy: 0.5096 - val_loss: 23947.9863
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9016 - loss: 184.6646 - val_accuracy: 0.5118 - val_loss: 23969.0449
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9078 - loss: 177.9322 - val_accuracy: 0.5118 - val_loss: 23975.4238
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9029 - loss: 174.1190 - val_accuracy: 0.5032 - val_loss: 23980.6348
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9004 - loss: 180.1971 - val_accuracy: 0.5075 - val_loss: 23978.3574
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9102 - loss: 164.1344 - val_accuracy: 0.5118 - val_loss: 23988.8438
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9016 - loss: 175.3999 - val_accuracy: 0.5075 - val_loss: 23984.4844
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9139 - loss: 155.4779 - val_accuracy: 0.5096 - val_loss: 23995.0859
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9114 - loss: 154.4420 - val_accuracy: 0.5118 - val_loss: 24018.7422
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9169 - loss: 147.1904 - val_accuracy: 0.5118 - val_loss: 24051.5059
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9175 - loss: 142.9389 - val_accuracy: 0.5118 - val_loss: 24079.8047
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9145 - loss: 142.1005 - val_accuracy: 0.5118 - val_loss: 24113.6895
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9236 - loss: 134.6919 - val_accuracy: 0.5096 - val_loss: 24150.3359
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9212 - loss: 133.5336 - val_accuracy: 0.5118 - val_loss: 24141.0684
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9236 - loss: 127.3817 - val_accuracy: 0.5096 - val_loss: 24124.7402
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9249 - loss: 122.1114 - val_accuracy: 0.5118 - val_loss: 24133.3789
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9243 - loss: 124.8772 - val_accuracy: 0.5096 - val_loss: 24159.7168
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9243 - loss: 115.6592 - val_accuracy: 0.5161 - val_loss: 24198.8945
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9175 - loss: 117.2573 - val_accuracy: 0.5161 - val_loss: 24335.9512
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9163 - loss: 134.6192 - val_accuracy: 0.5182 - val_loss: 24301.3281
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9273 - loss: 108.7184 - val_accuracy: 0.5118 - val_loss: 24285.9434
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9255 - loss: 104.9654 - val_accuracy: 0.5139 - val_loss: 24267.3965
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9243 - loss: 101.8544 - val_accuracy: 0.5139 - val_loss: 24277.2656
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9249 - loss: 104.4465 - val_accuracy: 0.5161 - val_loss: 24304.7070
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9224 - loss: 99.0973 - val_accuracy: 0.5161 - val_loss: 24318.5332
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9267 - loss: 95.6124 - val_accuracy: 0.5118 - val_loss: 24326.5020
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9322 - loss: 92.4317 - val_accuracy: 0.5075 - val_loss: 24332.6719
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9291 - loss: 90.6317 - val_accuracy: 0.5096 - val_loss: 24327.7129
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9297 - loss: 87.3040 - val_accuracy: 0.5118 - val_loss: 24318.0586
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9328 - loss: 84.6511 - val_accuracy: 0.5118 - val_loss: 24318.4277
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9297 - loss: 82.8465 - val_accuracy: 0.5161 - val_loss: 24287.6855
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9304 - loss: 80.1747 - val_accuracy: 0.5139 - val_loss: 24278.0195
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9322 - loss: 80.9109 - val_accuracy: 0.5161 - val_loss: 24232.7988
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9359 - loss: 75.7385 - val_accuracy: 0.5182 - val_loss: 24196.9746
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9389 - loss: 74.3399 - val_accuracy: 0.5182 - val_loss: 24181.5273
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9426 - loss: 70.8086 - val_accuracy: 0.5182 - val_loss: 24180.4902
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9444 - loss: 69.4221 - val_accuracy: 0.5182 - val_loss: 24185.0840
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9426 - loss: 69.9363 - val_accuracy: 0.5161 - val_loss: 24113.4902
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9420 - loss: 64.4064 - val_accuracy: 0.5161 - val_loss: 24067.0938
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9365 - loss: 64.6358 - val_accuracy: 0.5161 - val_loss: 24059.6465
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9432 - loss: 61.2290 - val_accuracy: 0.5139 - val_loss: 24061.2129
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9371 - loss: 65.7264 - val_accuracy: 0.5161 - val_loss: 24044.5488
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9432 - loss: 59.4606 - val_accuracy: 0.5182 - val_loss: 24073.1387
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9395 - loss: 61.1745 - val_accuracy: 0.5161 - val_loss: 24122.7520
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9450 - loss: 55.4361 - val_accuracy: 0.5161 - val_loss: 24173.3789
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9352 - loss: 65.9048 - val_accuracy: 0.5182 - val_loss: 24186.6152
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9456 - loss: 52.8452 - val_accuracy: 0.5203 - val_loss: 24207.4277
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9371 - loss: 57.6796 - val_accuracy: 0.5182 - val_loss: 24227.8594
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9524 - loss: 50.5702 - val_accuracy: 0.5203 - val_loss: 24239.2930
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9499 - loss: 49.6174 - val_accuracy: 0.5203 - val_loss: 24257.3535
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9481 - loss: 49.3983 - val_accuracy: 0.5161 - val_loss: 24244.2461
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9505 - loss: 48.9172 - val_accuracy: 0.5225 - val_loss: 24192.3398
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9560 - loss: 46.2765 - val_accuracy: 0.5225 - val_loss: 24151.0215
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9499 - loss: 45.4465 - val_accuracy: 0.5225 - val_loss: 24118.7324
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9475 - loss: 44.1245 - val_accuracy: 0.5182 - val_loss: 24093.6875
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9462 - loss: 42.9108 - val_accuracy: 0.5161 - val_loss: 24085.4844
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9487 - loss: 41.2921 - val_accuracy: 0.5182 - val_loss: 24082.3730
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9536 - loss: 39.8520 - val_accuracy: 0.5182 - val_loss: 24080.5352
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9566 - loss: 38.4585 - val_accuracy: 0.5182 - val_loss: 24081.9180
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9591 - loss: 37.3666 - val_accuracy: 0.5161 - val_loss: 24084.8086
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9603 - loss: 36.7004 - val_accuracy: 0.5161 - val_loss: 24082.2832
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9591 - loss: 36.0261 - val_accuracy: 0.5161 - val_loss: 24083.7871
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9603 - loss: 35.0404 - val_accuracy: 0.5161 - val_loss: 24088.8184
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9615 - loss: 34.0688 - val_accuracy: 0.5161 - val_loss: 24093.5391
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9621 - loss: 33.1450 - val_accuracy: 0.5182 - val_loss: 24104.7832
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9621 - loss: 32.2967 - val_accuracy: 0.5161 - val_loss: 24113.3301
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9633 - loss: 31.6389 - val_accuracy: 0.5161 - val_loss: 24115.4316
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9646 - loss: 30.7421 - val_accuracy: 0.5161 - val_loss: 24120.5254
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9652 - loss: 29.9227 - val_accuracy: 0.5161 - val_loss: 24121.4941
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9682 - loss: 29.2191 - val_accuracy: 0.5139 - val_loss: 24122.9609
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9676 - loss: 28.5993 - val_accuracy: 0.5139 - val_loss: 24124.9023
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9688 - loss: 28.0337 - val_accuracy: 0.5182 - val_loss: 24131.9902
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9707 - loss: 27.3849 - val_accuracy: 0.5182 - val_loss: 24139.9941
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9713 - loss: 26.8286 - val_accuracy: 0.5203 - val_loss: 24147.4531
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9713 - loss: 26.3066 - val_accuracy: 0.5182 - val_loss: 24155.6426
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9719 - loss: 25.7173 - val_accuracy: 0.5161 - val_loss: 24164.7930
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9707 - loss: 25.2180 - val_accuracy: 0.5161 - val_loss: 24174.0703
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9707 - loss: 24.7638 - val_accuracy: 0.5161 - val_loss: 24182.8691
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9743 - loss: 24.3568 - val_accuracy: 0.5161 - val_loss: 24186.9512
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9743 - loss: 23.8631 - val_accuracy: 0.5203 - val_loss: 24194.6016
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9750 - loss: 24.0330 - val_accuracy: 0.5182 - val_loss: 24230.1309
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9640 - loss: 26.5834 - val_accuracy: 0.5203 - val_loss: 24244.4121
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9701 - loss: 24.0571 - val_accuracy: 0.5203 - val_loss: 24258.3613
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9658 - loss: 25.4329 - val_accuracy: 0.5225 - val_loss: 24265.1973
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9664 - loss: 25.4425 - val_accuracy: 0.5225 - val_loss: 24255.3398
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9713 - loss: 24.2121 - val_accuracy: 0.5246 - val_loss: 24247.5645
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9756 - loss: 24.0589 - val_accuracy: 0.5246 - val_loss: 24243.4160
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9731 - loss: 23.6538 - val_accuracy: 0.5268 - val_loss: 24242.6855
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9719 - loss: 23.2395 - val_accuracy: 0.5246 - val_loss: 24239.6426
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9756 - loss: 22.6757 - val_accuracy: 0.5246 - val_loss: 24229.4453
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9737 - loss: 22.1877 - val_accuracy: 0.5268 - val_loss: 24221.1934
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9737 - loss: 21.5213 - val_accuracy: 0.5268 - val_loss: 24204.9570
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9768 - loss: 21.0880 - val_accuracy: 0.5246 - val_loss: 24190.5547
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9762 - loss: 20.8128 - val_accuracy: 0.5246 - val_loss: 24178.7246
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9768 - loss: 20.6281 - val_accuracy: 0.5203 - val_loss: 24179.2812
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9774 - loss: 20.1040 - val_accuracy: 0.5203 - val_loss: 24179.5996
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9798 - loss: 19.8166 - val_accuracy: 0.5203 - val_loss: 24178.1152

# %%
import matplotlib.pyplot as plt
from matplotlib import style
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt
import os

if not os.path.exists('images'):
    os.makedirs('images')

plt.style.use('seaborn-v0_8-bright')
fit, axes = plt.subplots(2, 1, figsize = (16, 12))

axes[0].set_title("LOSS")
axes[0].set_yscale("log")
axes[0].plot(train_history.history["loss"], label = "Training")
axes[0].plot(train_history.history["val_loss"], label = "Validation")
axes[0].legend()


axes[1].set_title("Accuracy")
axes[1].plot(train_history.history["accuracy"], label = "Training")
axes[1].plot(train_history.history["val_accuracy"], label = "Validation")
axes[1].set_xlabel("Epoch")
axes[1].legend()

# save plot
plt.figure(1)
plt.savefig('images/training_history.png')

# %% [markdown]
# # Evaluate model

# %%
from keras.utils import to_categorical
model.evaluate(x_test, to_categorical(y_test))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4822 - loss: 93421.5938
# [92291.3359375, 0.47685185074806213]

# %%
from tensorflow.math import argmax, confusion_matrix

y_pred_prob = model.predict(x_test)
y_pred = argmax(y_pred_prob, axis = -1)
cm = confusion_matrix(y_test, y_pred, num_classes = len(CLASSES)).numpy()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# # Confusion matrix

# %%
from tensorflow.math import argmax, confusion_matrix

y_pred_prob = model.predict(x_test)
y_pred = argmax(y_pred_prob, axis=-1)
cm = confusion_matrix(y_test, y_pred, num_classes=len(CLASSES)).numpy()

cm
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[50, 58],
#        [55, 53]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 4))
sns.heatmap(cm, xticklabels= CLASSES, yticklabels=CLASSES, annot=True, fmt = 'g', cmap='viridis')

plt.xlabel("Prediction")
plt.ylabel("Label")
# Out:
# Text(33.22222222222222, 0.5, 'Label')

# %%
n_bull_pred = cm[LABEL_BULL, LABEL_BULL] + cm[LABEL_BEAR, LABEL_BULL]
n_bull_true_pos = cm[LABEL_BULL, LABEL_BULL]
bull_accuracy = n_bull_true_pos / n_bull_pred if n_bull_pred > 0 else 0

n_bear_pred = cm[LABEL_BULL, LABEL_BEAR] + cm[LABEL_BEAR, LABEL_BEAR]
n_bear_true_pos = cm[LABEL_BEAR, LABEL_BEAR]
bear_accuracy = n_bear_true_pos / n_bear_pred if n_bear_pred > 0 else 0

n_total_pred = n_bull_pred + n_bear_pred
n_total_true_pos = n_bull_true_pos + n_bear_true_pos
total_accuracy = n_total_true_pos / n_total_pred if n_total_pred > 0 else 0

pd.DataFrame([{"Prediction": "Bull", "Accuracy": bull_accuracy},
              {"Prediction": "Bear", "Accuracy": bear_accuracy},
              {"Prediction": "Total", "Accuracy": total_accuracy}
              ])
# Out:
#   Prediction  Accuracy
# 0       Bull  0.476190
# 1       Bear  0.477477
# 2      Total  0.476852
